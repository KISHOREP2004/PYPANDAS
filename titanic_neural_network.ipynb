# %% [markdown]
# <a href="https://colab.research.google.com/github/KISHOREP2004/PYPANDAS/blob/main/titanic_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Load the datasets from the given URLs
train_url = "https://github.com/ezioauditore-tech/AI/raw/main/datasets/Titanic/train.csv"
test_url = "https://github.com/ezioauditore-tech/AI/raw/main/datasets/Titanic/test.csv"

train_data = pd.read_csv(train_url)
test_data = pd.read_csv(test_url)

# Preprocess the data
def preprocess_data(df):
    # Handle missing values
    df['Age'].fillna(df['Age'].median(), inplace=True)
    df['Fare'].fillna(df['Fare'].median(), inplace=True)
    df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

    # Convert categorical features to numerical
    df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
    df['Embarked'] = df['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})

    # Select features
    features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
    X = df[features]

    return X

X_train = preprocess_data(train_data)
y_train = train_data['Survived']

X_test = preprocess_data(test_data)

# Split the dataset into training and testing sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val), verbose=2)

# Evaluate the model on the test set
y_pred = (model.predict(X_val) > 0.5).astype("int32")
accuracy = accuracy_score(y_val, y_pred)
print(f"Validation Accuracy: {accuracy * 100:.2f}%")

# Predict on the test set
test_predictions = (model.predict(X_test) > 0.5).astype("int32")

# Assuming you want to save the predictions to a CSV file
output_df = pd.DataFrame({'PassengerId': test_data['PassengerId'], 'Survived': test_predictions.flatten()})
output_df.to_csv('titanic_predictions.csv', index=False)
# Out:
# Epoch 1/50
# 23/23 - 4s - loss: 0.6733 - accuracy: 0.6292 - val_loss: 0.6050 - val_accuracy: 0.7430 - 4s/epoch - 167ms/step
# Epoch 2/50
# 23/23 - 0s - loss: 0.5871 - accuracy: 0.7261 - val_loss: 0.5310 - val_accuracy: 0.7542 - 192ms/epoch - 8ms/step
# Epoch 3/50
# 23/23 - 0s - loss: 0.5333 - accuracy: 0.7570 - val_loss: 0.4854 - val_accuracy: 0.7486 - 313ms/epoch - 14ms/step
# Epoch 4/50
# 23/23 - 0s - loss: 0.4996 - accuracy: 0.7963 - val_loss: 0.4604 - val_accuracy: 0.7821 - 426ms/epoch - 19ms/step
# Epoch 5/50
# 23/23 - 0s - loss: 0.4783 - accuracy: 0.7795 - val_loss: 0.4465 - val_accuracy: 0.7933 - 254ms/epoch - 11ms/step
# Epoch 6/50
# 23/23 - 0s - loss: 0.4688 - accuracy: 0.7851 - val_loss: 0.4379 - val_accuracy: 0.7933 - 280ms/epoch - 12ms/step
# Epoch 7/50
# 23/23 - 0s - loss: 0.4705 - accuracy: 0.8048 - val_loss: 0.4332 - val_accuracy: 0.7989 - 371ms/epoch - 16ms/step
# Epoch 8/50
# 23/23 - 0s - loss: 0.4606 - accuracy: 0.8090 - val_loss: 0.4333 - val_accuracy: 0.7989 - 349ms/epoch - 15ms/step
# Epoch 9/50
# 23/23 - 0s - loss: 0.4494 - accuracy: 0.8076 - val_loss: 0.4308 - val_accuracy: 0.7989 - 434ms/epoch - 19ms/step
# Epoch 10/50
# 23/23 - 0s - loss: 0.4469 - accuracy: 0.8090 - val_loss: 0.4261 - val_accuracy: 0.8045 - 140ms/epoch - 6ms/step
# Epoch 11/50
# 23/23 - 0s - loss: 0.4461 - accuracy: 0.8090 - val_loss: 0.4282 - val_accuracy: 0.8045 - 109ms/epoch - 5ms/step
# Epoch 12/50
# 23/23 - 0s - loss: 0.4405 - accuracy: 0.8090 - val_loss: 0.4263 - val_accuracy: 0.7989 - 79ms/epoch - 3ms/step
# Epoch 13/50
# 23/23 - 0s - loss: 0.4470 - accuracy: 0.8062 - val_loss: 0.4299 - val_accuracy: 0.7989 - 77ms/epoch - 3ms/step
# Epoch 14/50
# 23/23 - 0s - loss: 0.4321 - accuracy: 0.8174 - val_loss: 0.4270 - val_accuracy: 0.8045 - 92ms/epoch - 4ms/step
# Epoch 15/50
# 23/23 - 0s - loss: 0.4369 - accuracy: 0.8062 - val_loss: 0.4282 - val_accuracy: 0.8045 - 85ms/epoch - 4ms/step
# Epoch 16/50
# 23/23 - 0s - loss: 0.4383 - accuracy: 0.8230 - val_loss: 0.4305 - val_accuracy: 0.8045 - 90ms/epoch - 4ms/step
# Epoch 17/50
# 23/23 - 0s - loss: 0.4425 - accuracy: 0.8090 - val_loss: 0.4274 - val_accuracy: 0.8101 - 75ms/epoch - 3ms/step
# Epoch 18/50
# 23/23 - 0s - loss: 0.4340 - accuracy: 0.8188 - val_loss: 0.4283 - val_accuracy: 0.8045 - 75ms/epoch - 3ms/step
# Epoch 19/50
# 23/23 - 0s - loss: 0.4191 - accuracy: 0.8132 - val_loss: 0.4263 - val_accuracy: 0.8045 - 76ms/epoch - 3ms/step
# Epoch 20/50
# 23/23 - 0s - loss: 0.4342 - accuracy: 0.8132 - val_loss: 0.4237 - val_accuracy: 0.8101 - 90ms/epoch - 4ms/step
# Epoch 21/50
# 23/23 - 0s - loss: 0.4322 - accuracy: 0.8118 - val_loss: 0.4214 - val_accuracy: 0.8101 - 91ms/epoch - 4ms/step
# Epoch 22/50
# 23/23 - 0s - loss: 0.4269 - accuracy: 0.8076 - val_loss: 0.4217 - val_accuracy: 0.8101 - 88ms/epoch - 4ms/step
# Epoch 23/50
# 23/23 - 0s - loss: 0.4366 - accuracy: 0.8188 - val_loss: 0.4224 - val_accuracy: 0.8045 - 75ms/epoch - 3ms/step
# Epoch 24/50
# 23/23 - 0s - loss: 0.4378 - accuracy: 0.8034 - val_loss: 0.4234 - val_accuracy: 0.8101 - 85ms/epoch - 4ms/step
# Epoch 25/50
# 23/23 - 0s - loss: 0.4228 - accuracy: 0.8174 - val_loss: 0.4231 - val_accuracy: 0.8101 - 89ms/epoch - 4ms/step
# Epoch 26/50
# 23/23 - 0s - loss: 0.4285 - accuracy: 0.8258 - val_loss: 0.4232 - val_accuracy: 0.8101 - 87ms/epoch - 4ms/step
# Epoch 27/50
# 23/23 - 0s - loss: 0.4261 - accuracy: 0.8062 - val_loss: 0.4215 - val_accuracy: 0.8212 - 92ms/epoch - 4ms/step
# Epoch 28/50
# 23/23 - 0s - loss: 0.4098 - accuracy: 0.8287 - val_loss: 0.4247 - val_accuracy: 0.8045 - 92ms/epoch - 4ms/step
# Epoch 29/50
# 23/23 - 0s - loss: 0.4178 - accuracy: 0.8230 - val_loss: 0.4300 - val_accuracy: 0.8045 - 85ms/epoch - 4ms/step
# Epoch 30/50
# 23/23 - 0s - loss: 0.4089 - accuracy: 0.8385 - val_loss: 0.4305 - val_accuracy: 0.8101 - 88ms/epoch - 4ms/step
# Epoch 31/50
# 23/23 - 0s - loss: 0.4250 - accuracy: 0.8230 - val_loss: 0.4278 - val_accuracy: 0.8101 - 108ms/epoch - 5ms/step
# Epoch 32/50
# 23/23 - 0s - loss: 0.4291 - accuracy: 0.8244 - val_loss: 0.4263 - val_accuracy: 0.8101 - 101ms/epoch - 4ms/step
# Epoch 33/50
# 23/23 - 0s - loss: 0.4170 - accuracy: 0.8188 - val_loss: 0.4247 - val_accuracy: 0.8212 - 82ms/epoch - 4ms/step
# Epoch 34/50
# 23/23 - 0s - loss: 0.4164 - accuracy: 0.8287 - val_loss: 0.4262 - val_accuracy: 0.8156 - 98ms/epoch - 4ms/step
# Epoch 35/50
# 23/23 - 0s - loss: 0.4244 - accuracy: 0.8188 - val_loss: 0.4293 - val_accuracy: 0.8101 - 99ms/epoch - 4ms/step
# Epoch 36/50
# 23/23 - 0s - loss: 0.4081 - accuracy: 0.8301 - val_loss: 0.4281 - val_accuracy: 0.8101 - 83ms/epoch - 4ms/step
# Epoch 37/50
# 23/23 - 0s - loss: 0.4174 - accuracy: 0.8343 - val_loss: 0.4273 - val_accuracy: 0.8156 - 92ms/epoch - 4ms/step
# Epoch 38/50
# 23/23 - 0s - loss: 0.4098 - accuracy: 0.8258 - val_loss: 0.4269 - val_accuracy: 0.8156 - 76ms/epoch - 3ms/step
# Epoch 39/50
# 23/23 - 0s - loss: 0.4321 - accuracy: 0.8202 - val_loss: 0.4257 - val_accuracy: 0.8156 - 88ms/epoch - 4ms/step
# Epoch 40/50
# 23/23 - 0s - loss: 0.4178 - accuracy: 0.8230 - val_loss: 0.4250 - val_accuracy: 0.8268 - 78ms/epoch - 3ms/step
# Epoch 41/50
# 23/23 - 0s - loss: 0.4247 - accuracy: 0.8343 - val_loss: 0.4293 - val_accuracy: 0.8101 - 85ms/epoch - 4ms/step
# Epoch 42/50
# 23/23 - 0s - loss: 0.4025 - accuracy: 0.8301 - val_loss: 0.4277 - val_accuracy: 0.8212 - 76ms/epoch - 3ms/step
# Epoch 43/50
# 23/23 - 0s - loss: 0.4181 - accuracy: 0.8357 - val_loss: 0.4301 - val_accuracy: 0.8156 - 92ms/epoch - 4ms/step
# Epoch 44/50
# 23/23 - 0s - loss: 0.4128 - accuracy: 0.8244 - val_loss: 0.4292 - val_accuracy: 0.8156 - 80ms/epoch - 3ms/step
# Epoch 45/50
# 23/23 - 0s - loss: 0.4032 - accuracy: 0.8357 - val_loss: 0.4271 - val_accuracy: 0.8156 - 102ms/epoch - 4ms/step
# Epoch 46/50
# 23/23 - 0s - loss: 0.4061 - accuracy: 0.8315 - val_loss: 0.4281 - val_accuracy: 0.8212 - 96ms/epoch - 4ms/step
# Epoch 47/50
# 23/23 - 0s - loss: 0.4165 - accuracy: 0.8287 - val_loss: 0.4282 - val_accuracy: 0.8212 - 81ms/epoch - 4ms/step
# Epoch 48/50
# 23/23 - 0s - loss: 0.4061 - accuracy: 0.8371 - val_loss: 0.4258 - val_accuracy: 0.8212 - 105ms/epoch - 5ms/step
# Epoch 49/50
# 23/23 - 0s - loss: 0.4070 - accuracy: 0.8174 - val_loss: 0.4307 - val_accuracy: 0.8101 - 76ms/epoch - 3ms/step
# Epoch 50/50
# 23/23 - 0s - loss: 0.4101 - accuracy: 0.8357 - val_loss: 0.4365 - val_accuracy: 0.8101 - 73ms/epoch - 3ms/step
# 6/6 [==============================] - 0s 2ms/step
# Validation Accuracy: 81.01%
# 14/14 [==============================] - 0s 2ms/step
